# %%
from agents import Agent, Runner
import os
import json
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
agent = Agent(name = "Manager", instructions="You are a manager who does the tasks provided to you.", model=)
